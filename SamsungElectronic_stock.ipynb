# %% [markdown]
# # 3.3.1 데이터 수집

# %%
conda install pandas-datareader
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# https://finance.yahoo.com/
import pandas as pd
import numpy as np
from pandas_datareader import data

# %% [markdown]
# (2021-07-12수정) 일시적으로 pandas-datareader 를 사용하여 주가 데이터를 못불러 오는 문제가 발생하였습니다.
#
#
# 야후 파이낸스(https://finance.yahoo.com/)에서 다운로드 받은 csv 파일을 직접 업로드해서 하도록 수정하였습니다.

# %%
# !pip install yfinance

import numpy as np
import pandas as pd
import yfinance as yfin
from pandas_datareader import data

yfin.pdr_override()
df = data.get_data_yahoo('005930.KS', start = '2020-01-01', end = '2021-06-30')
df
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51824.097656  12993228
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  52105.746094  15422255
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  52105.746094  10278951
# 2020-01-07  55700.0  56400.0  55600.0  55800.0  52387.406250  10009778
# 2020-01-08  56200.0  57400.0  55900.0  56800.0  53326.246094  23501171
# ...             ...      ...      ...      ...           ...       ...
# 2021-06-24  80400.0  81400.0  80100.0  81200.0  80097.882812  18771080
# 2021-06-25  81500.0  81900.0  81200.0  81600.0  80492.445312  13481405
# 2021-06-28  81700.0  82000.0  81600.0  81900.0  80788.375000  11578529
# 2021-06-29  81900.0  82100.0  80800.0  81000.0  80254.343750  15744317
# 2021-06-30  81100.0  81400.0  80700.0  80700.0  79957.109375  13288643
#
# [371 rows x 6 columns]

# %% [markdown]
#  시초가(Open), 고가(High), 저가(Low), 종가(Close), 수정종가(Adj Close), 거래량(Volume) 순으로 표시됩니다. 이중 수정 종가를 사용할 겁니다. ( 수정 종가 : 분할, 배당, 배분, 신주 발생이 된 경우를 고려해 주식 가격을 조정한 것, 데이터의 연속성을 위해서 수정 종가를 분석에 사용하는 경우가 많다고 합니다.  )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 371 entries, 2020-01-02 to 2021-06-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       371 non-null    float64
#  1   High       371 non-null    float64
#  2   Low        371 non-null    float64
#  3   Close      371 non-null    float64
#  4   Adj Close  371 non-null    float64
#  5   Volume     371 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 20.3 KB

# %% [markdown]
# # 3.3.2 데이터 가공

# %% [markdown]
# <div class="alert alert-success">
# [문제1]
#
#
# 데이터프레임(df)의 평균, 표준편차, 사분위수 등 주요 통계 지표를 확인하세요.
# </div>

# %%
df.describe()
# Out:
#                Open          High  ...     Adj Close        Volume
# count    371.000000    371.000000  ...    371.000000  3.710000e+02
# mean   65680.862534  66395.956873  ...  63315.101352  2.166475e+07
# std    13457.618572  13565.593793  ...  14118.555903  9.731540e+06
# min    42600.000000  43550.000000  ...  39900.804688  0.000000e+00
# 25%    54850.000000  55550.000000  ...  51873.546875  1.532923e+07
# 50%    60300.000000  60700.000000  ...  57081.613281  1.902332e+07
# 75%    81150.000000  81900.000000  ...  80018.687500  2.525948e+07
# max    90300.000000  96800.000000  ...  89367.742188  9.030618e+07
#
# [8 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제2]
#
#
# 종가('Close') 기준 최대값을 구하세요.
# </div>

# %%
df['Close'].max()
# Out:
# 91000.0

# %%
max(df['Close'])
# Out:
# 91000.0

# %% [markdown]
# <div class="alert alert-success">
# [문제3]
#
#
# 종가('Close') 기준 최소값을 구하세요.
# </div>

# %%
df['Close'].min()
# Out:
# 42500.0

# %%
min(df['Close'])
# Out:
# 42500.0

# %% [markdown]
# <div class="alert alert-success">
# [문제4]
#
#
# 종가('Close') 기준 평균값을 구하세요.
# </div>

# %%
df['Close'].mean()
# Out:
# 65670.88948787062

# %% [markdown]
# <div class="alert alert-success">
# [문제5]
#
#
# 총 데이터의 (row의 개수)를 확인하세요.
# </div>

# %%
df.shape
# Out:
# (371, 6)

# %%
# 방법1 
df.shape[0]

#(참고)컬럼갯수
# df.shape[1]
# Out:
# 371

# %%
# 방법2 
len(df)
# Out:
# 371

# %% [markdown]
# <div class="alert alert-success">
# [문제6]
#
#
# 특정 컬럼만 선택하세요.(예: ‘Close’ 컬럼만 선택, ‘Higt’와 ‘Low’ 두 개의 컬럼 선택)
# </div>

# %%
df['Close']
# Out:
# Date
# 2020-01-02    55200.0
# 2020-01-03    55500.0
# 2020-01-06    55500.0
# 2020-01-07    55800.0
# 2020-01-08    56800.0
#                ...
# 2021-06-24    81200.0
# 2021-06-25    81600.0
# 2021-06-28    81900.0
# 2021-06-29    81000.0
# 2021-06-30    80700.0
# Name: Close, Length: 371, dtype: float64

# %%
df[['High', 'Low']]
# Out:
#                High      Low
# Date
# 2020-01-02  56000.0  55000.0
# 2020-01-03  56600.0  54900.0
# 2020-01-06  55600.0  54600.0
# 2020-01-07  56400.0  55600.0
# 2020-01-08  57400.0  55900.0
# ...             ...      ...
# 2021-06-24  81400.0  80100.0
# 2021-06-25  81900.0  81200.0
# 2021-06-28  82000.0  81600.0
# 2021-06-29  82100.0  80800.0
# 2021-06-30  81400.0  80700.0
#
# [371 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제7]
#
#
# 상위 3개의 로우만 선택하세요.
# </div>

# %%
# df[:3]
df.head(3)
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51824.097656  12993228
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  52105.746094  15422255
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  52105.746094  10278951

# %% [markdown]
# <div class="alert alert-success">
# [문제8]
#
# 시작가('Open') 대비 종가('Close')가 높았던 날의 데이터만 선택하세요.
# </div>

# %%
df1 = df[df['Open'] <= df['Close']]
df1[['Open','Close']]
# Out:
#                Open    Close
# Date
# 2020-01-06  54900.0  55500.0
# 2020-01-07  55700.0  55800.0
# 2020-01-08  56200.0  56800.0
# 2020-01-09  58400.0  58600.0
# 2020-01-10  58800.0  59500.0
# ...             ...      ...
# 2021-06-16  81500.0  81800.0
# 2021-06-21  79700.0  79900.0
# 2021-06-24  80400.0  81200.0
# 2021-06-25  81500.0  81600.0
# 2021-06-28  81700.0  81900.0
#
# [185 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제9]
#
# 종가('Close') 기준 가장 주가가 높았던 날의 데이터(로우)를 선택하세요.
# </div>

# %%
df[df['Close'] == df['Close'].max()].index
# Out:
# DatetimeIndex(['2021-01-11'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
df[df['Close'] == max(df['Close'])]
# Out:
#              Open   High    Low  Close    Adj Close    Volume
# Date
# 2021-01-11  90000  96800  89500  91000  90597.41406  90306177

# %% [markdown]
# <div class="alert alert-success">
# [문제 10]
#
#  종가('Close') 기준 주가가 90,000원 이상이었던 날짜를 반환하세요.
# </div>

# %%
df[df['Close'] >= 90000].index
# Out:
# DatetimeIndex(['2021-01-11', '2021-01-12'], dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# <div class="alert alert-success">
# [문제 11]
#
# 2021년 1월 15일의 데이터를 반환하세요.
# </div>

# %%
df.head()
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51824.097656  12993228
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  52105.746094  15422255
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  52105.746094  10278951
# 2020-01-07  55700.0  56400.0  55600.0  55800.0  52387.406250  10009778
# 2020-01-08  56200.0  57400.0  55900.0  56800.0  53326.246094  23501171

# %%
df.iloc[300]
# Out:
# Open         8.200000e+04
# High         8.230000e+04
# Low          8.170000e+04
# Close        8.200000e+04
# Adj Close    8.052917e+04
# Volume       1.267051e+07
# Name: 2021-03-22 00:00:00, dtype: float64

# %%
df.loc['2021-01-15']
# Out:
# Open         8.980000e+04
# High         9.180000e+04
# Low          8.800000e+04
# Close        8.800000e+04
# Adj Close    8.761069e+04
# Volume       3.343181e+07
# Name: 2021-01-15, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# [문제 12]
#
# 2021년 1월 11일의 고가('High')와 저가('Low')값을 반환하세요.
# </div>

# %%
df.loc['2021-01-11'][['High','Low']]
# Out:
# High    96800.0
# Low     89500.0
# Name: 2021-01-11 00:00:00, dtype: float64

# %%
df.loc['2021-01-11', ['High', 'Low']]
# Out:
# High    96800.0
# Low     89500.0
# Name: 2021-01-11, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# [문제 13]
#
# 데이터프레임(df)의 100번째 데이터를 선택하세요.
# </div>

# %%
df.iloc[100]
# Out:
# Open         5.000000e+04
# High         5.070000e+04
# Low          4.970000e+04
# Close        5.070000e+04
# Adj Close    4.861053e+04
# Volume       2.759696e+07
# Name: 2020-05-29, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# [문제 14]
#
# 데이터를 날짜 역순으로(최신 데이터가 위에 위치하도록) 정렬하세요.
# </div>

# %%
df.sort_index(ascending=False)
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2021-06-30  81100.0  81400.0  80700.0  80700.0  79957.109375  13288643
# 2021-06-29  81900.0  82100.0  80800.0  81000.0  80254.343750  15744317
# 2021-06-28  81700.0  82000.0  81600.0  81900.0  80788.375000  11578529
# 2021-06-25  81500.0  81900.0  81200.0  81600.0  80492.445312  13481405
# 2021-06-24  80400.0  81400.0  80100.0  81200.0  80097.882812  18771080
# ...             ...      ...      ...      ...           ...       ...
# 2020-01-08  56200.0  57400.0  55900.0  56800.0  53326.246094  23501171
# 2020-01-07  55700.0  56400.0  55600.0  55800.0  52387.406250  10009778
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  52105.746094  10278951
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  52105.746094  15422255
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51824.097656  12993228
#
# [371 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 15]
#
# 종가(‘Close’) 데이터를 가격이 높은 순서대로 정렬하세요.
# </div>

# %%
df['Close'].sort_values(ascending=False)
# Out:
# Date
# 2021-01-11    91000.0
# 2021-01-12    90600.0
# 2021-01-14    89700.0
# 2021-01-13    89700.0
# 2021-01-25    89400.0
#                ...
# 2020-04-01    45800.0
# 2020-03-18    45600.0
# 2020-03-20    45400.0
# 2020-03-19    42950.0
# 2020-03-23    42500.0
# Name: Close, Length: 371, dtype: float64

# %%
df.sort_values(by='Close', ascending=False)
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2021-01-11  90000.0  96800.0  89500.0  91000.0  89367.742188  90306177
# 2021-01-12  90300.0  91400.0  87800.0  90600.0  88974.921875  48682416
# 2021-01-14  88700.0  90000.0  88700.0  89700.0  88091.062500  26393970
# 2021-01-13  89800.0  91200.0  89100.0  89700.0  88091.062500  36068848
# 2021-01-25  87000.0  89900.0  86300.0  89400.0  87796.445312  27258534
# ...             ...      ...      ...      ...           ...       ...
# 2020-04-01  47450.0  47900.0  45800.0  45800.0  43316.457031  27259532
# 2020-03-18  47750.0  48350.0  45600.0  45600.0  42811.210938  40152623
# 2020-03-20  44150.0  45500.0  43550.0  45400.0  42623.445312  49730008
# 2020-03-19  46400.0  46650.0  42300.0  42950.0  40323.277344  56925513
# 2020-03-23  42600.0  43550.0  42400.0  42500.0  39900.804688  41701626
#
# [371 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 16]
#
# 인덱스 컬럼을 0부터 순차적으로 증가하는 정수로 변경하세요.
# </div>

# %%
#방법 1: 인덱스값이 신규 컬럼으로 생성
df.reset_index(inplace=True)

# 방법 2: 새로운 필드 df['Date']를 만들어 index를 할당
# df['Date'] = df.index

df
# Out:
#           Date     Open     High      Low    Close     Adj Close    Volume
# 0   2020-01-02  55500.0  56000.0  55000.0  55200.0  51824.097656  12993228
# 1   2020-01-03  56000.0  56600.0  54900.0  55500.0  52105.746094  15422255
# 2   2020-01-06  54900.0  55600.0  54600.0  55500.0  52105.746094  10278951
# 3   2020-01-07  55700.0  56400.0  55600.0  55800.0  52387.406250  10009778
# 4   2020-01-08  56200.0  57400.0  55900.0  56800.0  53326.246094  23501171
# ..         ...      ...      ...      ...      ...           ...       ...
# 366 2021-06-24  80400.0  81400.0  80100.0  81200.0  80097.882812  18771080
# 367 2021-06-25  81500.0  81900.0  81200.0  81600.0  80492.445312  13481405
# 368 2021-06-28  81700.0  82000.0  81600.0  81900.0  80788.375000  11578529
# 369 2021-06-29  81900.0  82100.0  80800.0  81000.0  80254.343750  15744317
# 370 2021-06-30  81100.0  81400.0  80700.0  80700.0  79957.109375  13288643
#
# [371 rows x 7 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 17]
#
# 컬럼명을 Date는 ‘날짜’로, ‘High’는 ‘고가’로, ‘Low’는 ‘저가’로 변경하세요.
# </div>

# %%
df.rename(columns={'Date': '날짜', 'High': '고가', 'Low': '저가'})
# Out:
#              날짜   Open     고가     저가  Close    Adj Close    Volume
# 0    2020-01-02  55500  56000  55000  55200  52537.17969  12993228
# 1    2020-01-03  56000  56600  54900  55500  52822.70703  15422255
# 2    2020-01-06  54900  55600  54600  55500  52822.70703  10278951
# 3    2020-01-07  55700  56400  55600  55800  53108.23828  10009778
# 4    2020-01-08  56200  57400  55900  56800  54059.99219  23501171
# ..          ...    ...    ...    ...    ...          ...       ...
# 358  2021-06-14  80800  80900  80500  80500  80500.00000  10550078
# 359  2021-06-15  80900  81200  80600  80900  80900.00000  10075685
# 360  2021-06-16  81500  81900  81100  81800  81800.00000  14999855
# 361  2021-06-17  81100  81300  80700  80900  80900.00000  14007385
# 362  2021-06-18  81100  81100  80500  80500  80500.00000  14916721
#
# [363 rows x 7 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 18]
#
# 날짜(‘Date’) 컬럼을 삭제하세요.
# </div>

# %%
df.drop(columns=['Date']) # inplace = True
# Out:
#       Open   High    Low  Close    Adj Close    Volume
# 0    55500  56000  55000  55200  52537.17969  12993228
# 1    56000  56600  54900  55500  52822.70703  15422255
# 2    54900  55600  54600  55500  52822.70703  10278951
# 3    55700  56400  55600  55800  53108.23828  10009778
# 4    56200  57400  55900  56800  54059.99219  23501171
# ..     ...    ...    ...    ...          ...       ...
# 358  80800  80900  80500  80500  80500.00000  10550078
# 359  80900  81200  80600  80900  80900.00000  10075685
# 360  81500  81900  81100  81800  81800.00000  14999855
# 361  81100  81300  80700  80900  80900.00000  14007385
# 362  81100  81100  80500  80500  80500.00000  14916721
#
# [363 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 19]
#
#  'diff’ 컬럼을 생성하고, 종가(‘Close’)와 시가(‘Open’)의 차이를 계산하여 채워주세요
# </div>

# %%
df['diff'] = df['Close']-df['Open']
df
# Out:
#            Date   Open   High    Low  Close    Adj Close    Volume  diff
# 0    2020-01-02  55500  56000  55000  55200  52537.17969  12993228  -300
# 1    2020-01-03  56000  56600  54900  55500  52822.70703  15422255  -500
# 2    2020-01-06  54900  55600  54600  55500  52822.70703  10278951   600
# 3    2020-01-07  55700  56400  55600  55800  53108.23828  10009778   100
# 4    2020-01-08  56200  57400  55900  56800  54059.99219  23501171   600
# ..          ...    ...    ...    ...    ...          ...       ...   ...
# 358  2021-06-14  80800  80900  80500  80500  80500.00000  10550078  -300
# 359  2021-06-15  80900  81200  80600  80900  80900.00000  10075685     0
# 360  2021-06-16  81500  81900  81100  81800  81800.00000  14999855   300
# 361  2021-06-17  81100  81300  80700  80900  80900.00000  14007385  -200
# 362  2021-06-18  81100  81100  80500  80500  80500.00000  14916721  -600
#
# [363 rows x 8 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 20]
#
#  ‘Date’ 필드에 저장된 값을 파싱하여 ‘Year’, ‘Month’, ‘Day’ 필드에 저장하세요
# </div>

# %% [markdown]
# (2021-07-12수정)
# 'Date' 컬럼을 'datetime64' 타입으로 변경하는 코드 추가

# %%
df['Date'] = df['Date'].astype('datetime64')
df['Year'] = [d.year for d in df['Date']]
df['Month'] = [d.month for d in df['Date']]
df['Day'] = [d.day for d in df['Date']]
df
# Out:
#           Date   Open   High    Low  Close    Adj Close    Volume  diff  Year  \
# 0   2020-01-02  55500  56000  55000  55200  52537.17969  12993228  -300  2020
# 1   2020-01-03  56000  56600  54900  55500  52822.70703  15422255  -500  2020
# 2   2020-01-06  54900  55600  54600  55500  52822.70703  10278951   600  2020
# 3   2020-01-07  55700  56400  55600  55800  53108.23828  10009778   100  2020
# 4   2020-01-08  56200  57400  55900  56800  54059.99219  23501171   600  2020
# ..         ...    ...    ...    ...    ...          ...       ...   ...   ...
# 358 2021-06-14  80800  80900  80500  80500  80500.00000  10550078  -300  2021
# 359 2021-06-15  80900  81200  80600  80900  80900.00000  10075685     0  2021
# 360 2021-06-16  81500  81900  81100  81800  81800.00000  14999855   300  2021
# 361 2021-06-17  81100  81300  80700  80900  80900.00000  14007385  -200  2021
# 362 2021-06-18  81100  81100  80500  80500  80500.00000  14916721  -600  2021
#
#      Month  Day
# 0        1    2
# 1        1    3
# 2        1    6
# 3        1    7
# 4        1    8
# ..     ...  ...
# 358      6   14
# 359      6   15
# 360      6   16
# 361      6   17
# 362      6   18
#
# [363 rows x 11 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 21]
#
# 수정된 종가('Adj Close') 데이터를 소수점 둘째자리까지 표시하세요
# </div>

# %%
format = lambda x: '%.2f' % x
df['Adj Close'] = df['Adj Close'].apply(format)
df
# Out:
#           Date   Open   High    Low  Close Adj Close    Volume  diff  Year  \
# 0   2020-01-02  55500  56000  55000  55200  52537.18  12993228  -300  2020
# 1   2020-01-03  56000  56600  54900  55500  52822.71  15422255  -500  2020
# 2   2020-01-06  54900  55600  54600  55500  52822.71  10278951   600  2020
# 3   2020-01-07  55700  56400  55600  55800  53108.24  10009778   100  2020
# 4   2020-01-08  56200  57400  55900  56800  54059.99  23501171   600  2020
# ..         ...    ...    ...    ...    ...       ...       ...   ...   ...
# 358 2021-06-14  80800  80900  80500  80500  80500.00  10550078  -300  2021
# 359 2021-06-15  80900  81200  80600  80900  80900.00  10075685     0  2021
# 360 2021-06-16  81500  81900  81100  81800  81800.00  14999855   300  2021
# 361 2021-06-17  81100  81300  80700  80900  80900.00  14007385  -200  2021
# 362 2021-06-18  81100  81100  80500  80500  80500.00  14916721  -600  2021
#
#      Month  Day
# 0        1    2
# 1        1    3
# 2        1    6
# 3        1    7
# 4        1    8
# ..     ...  ...
# 358      6   14
# 359      6   15
# 360      6   16
# 361      6   17
# 362      6   18
#
# [363 rows x 11 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 22]
#
# 거래량 필드를 생성하고 , 가 들어가도록 변경하기(예: 16949183.0 -> 16,949,183)
# </div>

# %%
df['거래량'] = df['Volume'].apply(lambda x : "{:,}".format(x))
df
# Out:
#           Date   Open   High    Low  Close Adj Close    Volume  diff  Year  \
# 0   2020-01-02  55500  56000  55000  55200  52537.18  12993228  -300  2020
# 1   2020-01-03  56000  56600  54900  55500  52822.71  15422255  -500  2020
# 2   2020-01-06  54900  55600  54600  55500  52822.71  10278951   600  2020
# 3   2020-01-07  55700  56400  55600  55800  53108.24  10009778   100  2020
# 4   2020-01-08  56200  57400  55900  56800  54059.99  23501171   600  2020
# ..         ...    ...    ...    ...    ...       ...       ...   ...   ...
# 358 2021-06-14  80800  80900  80500  80500  80500.00  10550078  -300  2021
# 359 2021-06-15  80900  81200  80600  80900  80900.00  10075685     0  2021
# 360 2021-06-16  81500  81900  81100  81800  81800.00  14999855   300  2021
# 361 2021-06-17  81100  81300  80700  80900  80900.00  14007385  -200  2021
# 362 2021-06-18  81100  81100  80500  80500  80500.00  14916721  -600  2021
#
#      Month  Day         거래량
# 0        1    2  12,993,228
# 1        1    3  15,422,255
# 2        1    6  10,278,951
# 3        1    7  10,009,778
# 4        1    8  23,501,171
# ..     ...  ...         ...
# 358      6   14  10,550,078
# 359      6   15  10,075,685
# 360      6   16  14,999,855
# 361      6   17  14,007,385
# 362      6   18  14,916,721
#
# [363 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 23]
#
# 주가 데이터를 월(‘Month’)별로 그룹핑하고, 거래량(‘Volume’)의 평균값을 표시하세요.
# </div>

# %%
volume_mean = df['Volume'].groupby(df['Month']).mean()
volume_mean
# Out:
# Month
# 1     2.713407e+07
# 2     2.086738e+07
# 3     2.649870e+07
# 4     1.897715e+07
# 5     1.911778e+07
# 6     2.044393e+07
# 7     1.901368e+07
# 8     2.008490e+07
# 9     2.030011e+07
# 10    1.723988e+07
# 11    2.363959e+07
# 12    2.523804e+07
# Name: Volume, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# [문제 24]
#
# 결측치가 있는지 확인하고, 결측치가 있을 경우 결측치를 처리하세요.
# </div>

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# diff         0
# Year         0
# Month        0
# Day          0
# 거래량          0
# dtype: int64

# %%
df.dropna()  # 결측치 삭제

df.fillna({'High': 90000, 'Low': 50000}) # 결측치 치환 예시
# Out:
#           Date   Open   High    Low  Close Adj Close    Volume  diff  Year  \
# 0   2020-01-02  55500  56000  55000  55200  52537.18  12993228  -300  2020
# 1   2020-01-03  56000  56600  54900  55500  52822.71  15422255  -500  2020
# 2   2020-01-06  54900  55600  54600  55500  52822.71  10278951   600  2020
# 3   2020-01-07  55700  56400  55600  55800  53108.24  10009778   100  2020
# 4   2020-01-08  56200  57400  55900  56800  54059.99  23501171   600  2020
# ..         ...    ...    ...    ...    ...       ...       ...   ...   ...
# 358 2021-06-14  80800  80900  80500  80500  80500.00  10550078  -300  2021
# 359 2021-06-15  80900  81200  80600  80900  80900.00  10075685     0  2021
# 360 2021-06-16  81500  81900  81100  81800  81800.00  14999855   300  2021
# 361 2021-06-17  81100  81300  80700  80900  80900.00  14007385  -200  2021
# 362 2021-06-18  81100  81100  80500  80500  80500.00  14916721  -600  2021
#
#      Month  Day         거래량
# 0        1    2  12,993,228
# 1        1    3  15,422,255
# 2        1    6  10,278,951
# 3        1    7  10,009,778
# 4        1    8  23,501,171
# ..     ...  ...         ...
# 358      6   14  10,550,078
# 359      6   15  10,075,685
# 360      6   16  14,999,855
# 361      6   17  14,007,385
# 362      6   18  14,916,721
#
# [363 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
# [문제 25]
#
# 12월의 데이터와 11월의 데이터를 별도의 데이터프레임(dec_df, nov_df)으로 만들고 두 데
# 이터프레임을 하나의 데이터프레임으로 이어 붙이세요
# </div>

# %%
dec_df = df[df['Month']==12]
nov_df = df[df['Month']==11]

nov_dec_df = pd.concat([nov_df, dec_df])

nov_dec_df
# Out:
#           Date   Open   High    Low  Close Adj Close    Volume  diff  Year  \
# 206 2020-11-02  56400  57500  56000  57400  55743.18  20489076  1000  2020
# 207 2020-11-03  57900  58900  57600  58800  57102.78  14950919   900  2020
# 208 2020-11-04  58900  59000  57800  58500  56811.43  21718561  -400  2020
# 209 2020-11-05  59000  60300  58800  60300  58559.48  20639475  1300  2020
# 210 2020-11-06  60700  60800  59600  60100  58365.25  16910230  -600  2020
# 211 2020-11-09  60700  60900  60100  60200  58462.36  15892961  -500  2020
# 212 2020-11-10  60500  60500  59500  60200  58462.36  19073552  -300  2020
# 213 2020-11-11  60700  61400  60400  61300  59530.61  25628510   600  2020
# 214 2020-11-12  61000  61400  60700  61000  59239.27  19800573     0  2020
# 215 2020-11-13  61300  63200  61000  63200  61375.77  31508829  1900  2020
# 216 2020-11-16  64000  66700  63900  66300  64386.29  36354334  2300  2020
# 217 2020-11-17  67000  67000  65600  65700  63803.61  30204089 -1300  2020
# 218 2020-11-18  65700  66200  64700  64800  62929.59  22963790  -900  2020
# 219 2020-11-19  64100  64800  63900  64600  62735.36  16590290   500  2020
# 220 2020-11-20  63900  65200  63900  64700  62832.48  15068682   800  2020
# 221 2020-11-23  64800  67800  64700  67500  65551.66  27134398  2700  2020
# 222 2020-11-24  67900  69500  67000  67700  65745.88  32158235  -200  2020
# 223 2020-11-25  67900  68300  66500  66600  64677.63  32447065 -1300  2020
# 224 2020-11-26  66100  68000  66000  68000  66037.22  19023323  1900  2020
# 225 2020-11-27  68000  68400  67600  68200  66231.45  14063434   200  2020
# 226 2020-11-30  68400  68600  66700  66700  64774.75  43811016 -1700  2020
# 227 2020-12-01  67100  68300  67100  67800  65842.99  22327173   700  2020
# 228 2020-12-02  68400  69900  68300  69500  67493.93  29703942  1100  2020
# 229 2020-12-03  70100  70500  69300  69700  67688.15  23677989  -400  2020
# 230 2020-12-04  70400  72100  70100  71500  69436.20  28130533  1100  2020
# 231 2020-12-07  72400  73500  71900  72900  70795.79  28490496   500  2020
# 232 2020-12-08  72200  72900  71600  71700  69630.43  25000338  -500  2020
# 233 2020-12-09  72100  73900  72000  73900  71766.92  24077996  1800  2020
# 234 2020-12-10  72700  73800  72500  72900  70795.79  39882928   200  2020
# 235 2020-12-11  73500  73800  73100  73400  71281.36  18486672  -100  2020
# 236 2020-12-14  73600  74500  73200  73800  71669.81  21510415   200  2020
# 237 2020-12-15  73800  74100  73300  73800  71669.81  20863671     0  2020
# 238 2020-12-16  74100  74500  73400  73800  71669.81  17512081  -300  2020
# 239 2020-12-17  73400  73700  72600  73300  71184.24  24293214  -100  2020
# 240 2020-12-18  73300  73700  73000  73000  70892.91  17613029  -300  2020
# 241 2020-12-21  73100  73400  72000  73000  70892.91  20367355  -100  2020
# 242 2020-12-22  72500  73200  72100  72300  70213.10  16304910  -200  2020
# 243 2020-12-23  72400  74000  72300  73900  71766.92  19411326  1500  2020
# 244 2020-12-24  74100  78800  74000  77800  75554.35  32502870  3700  2020
# 245 2020-12-28  79000  80100  78200  78700  76428.38  40085044  -300  2020
# 246 2020-12-29  78800  78900  77300  78300  77953.60  30339449  -500  2020
# 247 2020-12-30  77400  81300  77300  81000  80641.66  29417421  3600  2020
#
#      Month  Day         거래량
# 206     11    2  20,489,076
# 207     11    3  14,950,919
# 208     11    4  21,718,561
# 209     11    5  20,639,475
# 210     11    6  16,910,230
# 211     11    9  15,892,961
# 212     11   10  19,073,552
# 213     11   11  25,628,510
# 214     11   12  19,800,573
# 215     11   13  31,508,829
# 216     11   16  36,354,334
# 217     11   17  30,204,089
# 218     11   18  22,963,790
# 219     11   19  16,590,290
# 220     11   20  15,068,682
# 221     11   23  27,134,398
# 222     11   24  32,158,235
# 223     11   25  32,447,065
# 224     11   26  19,023,323
# 225     11   27  14,063,434
# 226     11   30  43,811,016
# 227     12    1  22,327,173
# 228     12    2  29,703,942
# 229     12    3  23,677,989
# 230     12    4  28,130,533
# 231     12    7  28,490,496
# 232     12    8  25,000,338
# 233     12    9  24,077,996
# 234     12   10  39,882,928
# 235     12   11  18,486,672
# 236     12   14  21,510,415
# 237     12   15  20,863,671
# 238     12   16  17,512,081
# 239     12   17  24,293,214
# 240     12   18  17,613,029
# 241     12   21  20,367,355
# 242     12   22  16,304,910
# 243     12   23  19,411,326
# 244     12   24  32,502,870
# 245     12   28  40,085,044
# 246     12   29  30,339,449
# 247     12   30  29,417,421
